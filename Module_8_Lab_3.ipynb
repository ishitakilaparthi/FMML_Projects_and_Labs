# %% [markdown]
# <a href="https://colab.research.google.com/github/ishitakilaparthi/FMML_Projects_and_Labs/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-06 08:48:53--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   126MB/s    in 0.5s
#
# 2024-04-06 08:48:53 (126 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5933    1302.7280v1  The task of clustering a set of objects based ...  stat
# 22889  1710.01788v1  Inferring predictive maps between multiple inp...  stat
# 26796  1611.09010v1  This paper addresses the problem of 3D human p...    cs
# 28158  1705.08101v1  In this paper, we discuss and review how combi...    cs
# 16364  1701.07880v1  This paper aims to make up for the lack of doc...    cs
# ...             ...                                                ...   ...
# 292    1703.06585v2  We introduce the first goal-driven training fo...    cs
# 12963  1607.08289v3  Characterizing human values is a topic deeply ...    cs
# 15060   1401.2663v1  In this study, a dictionary-based method is us...    cs
# 36076   1210.6128v1  Artificial bee colony (ABC), an optimization a...    cs
# 22837  1708.02999v1  We consider the demixing problem of two (or mo...  stat
#
#                                                    title  year  \
# 5933                       Bayesian Consensus Clustering  2013
# 22889  Multitask Learning using Task Clustering with ...  2017
# 26796  3D Human Pose Estimation from a Single Image v...  2016
# 28158  Towards seamless multi-view scene analysis fro...  2017
# 16364    emLam -- a Hungarian Language Modeling baseline  2017
# ...                                                  ...   ...
# 292    Learning Cooperative Visual Dialog Agents with...  2017
# 12963                            Mammalian Value Systems  2016
# 15060  Dictionary-Based Concept Mining: An Applicatio...  2014
# 36076  Improved Local Search in Artificial Bee Colony...  2012
# 22837  Demixing Structured Superposition Signals from...  2017
#
#                                                 keywords
# 5933   [clustering, applications, integrative, statis...
# 22889  [inferring, predictive, variables, innumerable...
# 26796  [addresses, estimation, detecting, observation...
# 28158  [satellite, information, detection, understand...
# 16364  [documented, baselines, hungarian, approaches,...
# ...                                                  ...
# 292    [introduce, answering, specifically, cooperati...
# 12963  [characterizing, interwoven, humanities, endea...
# 15060  [dictionary, expressive, documents, concerning...
# 36076  [artificial, optimization, algorithm, populati...
# 22837  [structured, dimensional, nonlinear, observati...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5933     [clustering, applications, integrative, statis...
# 22889    [inferring, predictive, variables, innumerable...
# 26796    [addresses, estimation, detecting, observation...
# 28158    [satellite, information, detection, understand...
# 16364    [documented, baselines, hungarian, approaches,...
#                                ...
# 10391    [probabilistic, numerical, posterior, statisti...
# 11381    [supporting, performance, stochastic, strategi...
# 13309    [algorithms, prediction, estimation, filtering...
# 17879    [particular, conversion, assignment, construct...
# 7475     [electronic, accumulating, populations, motiva...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8804 words.
# Out of those 4536 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ad6c7efa-e592-4f8b-a625-f4f68f111125" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad6c7efa-e592-4f8b-a625-f4f68f111125")) {                    Plotly.newPlot(                        "ad6c7efa-e592-4f8b-a625-f4f68f111125",                        [{"x":["identification","consensus","heterogeneous","applications","motivated","simultaneous","computationally","biomedical","demonstrate","estimation","application","independent","statistical","integrated","clustering","separately","integrative","framework","available","clusterings","individual","assumption","hierarchy","multitask","regression","structure","hierarchical","groupings","approximates","methodologies","variables","varieties","predictive","usefulness","interesting","discovering","automated","simultaneously","phenotypes","discovered","parameters","performance","perspective","information","automatically","inferring","coordinates","cartesian","predicted","naturally","positivity","promising","evaluation","regressor","approaches","generalization","observations","detecting","advantage","consistent","hypothesize","estimates","construction","qualitative","quantitative","architectures","representing","addresses","formulating","alternative","breakthroughs","reconstruction","detection","integrating","discussed","registration","described","strategies","challenges","potential","different","classification","viewpoint","fertilization","complementary","observation","illumination","understanding","impossible","acquisition","geographic","orientation","satellite","challenging","combination","represent","perplexity","baselines","benchmark","evaluated","hungarian","introduced","comparable","documented","processor","collected","automatic","efficiency","artificial","projection","processing","experiment","recognize","characters","character","algorithm","recognition","accurately","population","component","nonlinear","contrastive","selection","discovery","interpretations","desirable","geometrical","dependent","important","homogeneous","denoising","treatment","technique","principal","documentation","experiments","dimensional","standardization","visualizing","identifies","demonstrating","satisfies","guarantees","theoretical","deterministic","incomparable","translation","knowledge","transducer","canonical","existence","transducers","researchers","exploration","reduction","methodology","encodings","empirically","optimization","diversity","improvements","including","contextual","bootstrap","reinforcing","practitioners","remarkably","minimizing","practical","reference","algorithms","introduce","challenge","independently","representation","horizontal","especially","leaderboard","hippocampus","consequences","hippocampal","mechanism","formation","motivation","behaviorally","computation","modulation","complexity","implement","sensitive","convolutional","constrained","cognitive","biological","preserved","respectively","enclosing","unsupervised","extensive","randomized"],"y":[125,25,28,442,46,25,92,12,558,202,253,124,169,52,157,43,1,520,319,4,130,74,34,10,116,347,108,2,13,17,116,6,64,23,77,24,86,120,0,16,240,916,67,718,151,22,16,3,42,62,3,129,256,6,433,114,78,66,87,92,10,84,71,65,76,117,87,61,9,89,5,95,345,36,50,24,63,102,113,156,731,523,22,2,46,64,39,143,12,39,10,31,11,261,145,112,9,74,212,145,3,138,104,4,8,86,175,165,141,59,280,73,42,33,54,819,356,61,48,103,57,9,152,47,11,30,14,62,373,16,39,26,257,29,4,581,192,4,7,16,30,15,68,147,44,2,132,344,3,24,31,3,65,58,92,73,9,77,290,52,120,246,52,6,0,17,9,57,139,62,604,335,167,46,380,3,144,4,0,13,0,119,22,21,1,154,2,212,56,65,385,66,46,40,10,94,1,148,174,31],"type":"bar"},{"x":["identification","consensus","heterogeneous","applications","motivated","simultan ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4536,), (4536, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8166666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.6);'>Cascading</span> <span style=''>A</span> <span style=''>a</span> <span style=''>Parallel</span> <span style=''>Approach</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Heuristic</span> <span style=''>Search</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>proposed</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heuristic</span> <span style=''>search</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>Cascading</span> <span style=''>A</span> <span style=''>which</span> <span style=''>is</span> <span style=''>a</span> <span style=''>two</span> <span style=''>phrase</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.31612903225806455);'>combining</span> <span style=''>A</span> <span style=''>and</span> <span style=''>IDA</span> <span style=''>by</span> <span style=''>a</span> <span style=''>new</span> <span style=''>concept</span> <span style=''>envelope</span> <span style=''>ball</span> <span style=''>The</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>CA</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>able</span> <span style=''>to</span> <span style=''>generate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>solution</span> <span style=''>and</span> <span style=''>any</span> <span style=''>time</span> <span style=''>solution</span> <span style=''>and</span> <span style=''>parallel</span> <span style=''>friendly</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style=''>mixtures</span> <span style=''>of</span> <span style=''>spatial</span> <span style=''>spline</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regressions</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style=''>relates</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>model</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>for</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>data</span> <span style=''>where</span> <span style=''>the</span> <span style=''>data</span> <span style=''>are</span> <span style=''>surfaces</span> <span style=''>We</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>spatial</span> <span style=''>spline</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>model</span> <span style=''>with</span> <span style=''>mixed</span> <span style=''>effects</span> <span style=''>(BSSR)</span> <span style=''>for</span> <span style=''>modeling</span> <span style=''>spatial</span> <span style=''>function</span> <span style=''>data</span> <span style=''>The</span> <span style=''>BSSR</span> <span style=''>model</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Nodal</span> <span style=''>basis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>for</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accommodates</span> <span style=''>both</span> <span style=''>common</span> <span style=''>mean</span> <span style=''>behavior</span> <span style=''>for</span> <span style=''>the</span> <span style=''>data</span> <span style=''>through</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>effects</span> <span style=''>part</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variability</span> <span style=''>inter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individuals</span> <span style=''>thanks</span> <span style=''>to</span> <span style=''>a</span> <span style=''>random</span> <span style=''>effects</span> <span style=''>part</span> <span style=''>Then</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>populations</span> <span style=''>of</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>data</span> <span style=''>issued</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneous</span> <span style=''>groups</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrate</span> <span style=''>the</span> <span style=''>BSSR</span> <span style=''>model</span> <span style=''>into</span> <span style=''>a</span> <span style=''>mixture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>model</span> <span style=''>is</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>spatial</span> <span style=''>spline</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regressions</span> <span style=''>with</span> <span style=''>mixed</span> <span style=''>effects</span> <span style=''>(BMSSR)</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3626373626373626);'>Principal</span> <span style=''>Graphs</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Manifolds</span> <br/><br/><span style=''>In</span> <span style=''>many</span> <span style=''>physical</span> <span style='background-color:rgba(255, 0, 0, 0.3130081300813008);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>biological</span> <span style=''>and</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigations</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>desirable</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>a</span> <span style=''>system</span> <span style=''>of</span> <span style=''>points</span> <span style=''>by</span> <span style=''>objects</span> <span style=''>of</span> <span style=''>lower</span> <span style='background-color:rgba(255, 0, 0, 0.4000000000000001);'>dimension</span> <span style=''>andor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>For</span> <span style=''>this</span> <span style=''>purpose</span> <span style=''>Karl</span> <span style=''>Pearson</span> <span style=''>invented</span> <span style='background-color:rgba(255, 0, 0, 0.3626373626373626);'>principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>in</span> <span style=''>1901</span> <span style=''>and</span> <span style=''>found</span> <span style=''>lines</span> <span style=''>and</span> <span style=''>planes</span> <span style=''>of</span> <span style=''>closest</span> <span style=''>fit</span> <span style=''>to</span> <span style=''>system</span> <span style=''>of</span> <span style=''>points</span> <span style=''>The</span> <span style=''>famous</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>solves</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>problem</span> <span style=''>too</span> <span style=''>but</span> <span style=''>by</span> <span style=''>finite</span> <span style=''>sets</span> <span style=''>instead</span> <span style=''>of</span> <span style=''>lines</span> <span style=''>and</span> <span style=''>planes</span> <span style=''>This</span> <span style=''>chapter</span> <span style=''>gives</span> <span style=''>a</span> <span style=''>brief</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.320754716981132);'>introduction</span> <span style=''>into</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style=''>of</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3626373626373626);'>principal</span> <span style=''>objects</span> <span style=''>ie</span> <span style=''>objects</span> <span style=''>embedded</span> <span style=''>in</span> <span style=''>the</span> <span style=''>middle</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>multidimensional</span> <span style=''>data</span> <span style=''>set</span> <span style=''>As</span> <span style=''>a</span> <span style=''>basis</span> <span style=''>the</span> <span style=''>unifying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>mean</span> <span style=''>squared</span> <span style=''>distance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>finite</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>BaTFLED</span> <span style=''>Bayesian</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <span style=''>Linked</span> <span style=''>to</span> <span style=''>External</span> <span style=''>Data</span> <br/><br/><span style=''>The</span> <span style=''>vast</span> <span style=''>majority</span> <span style=''>of</span> <span style=''>current</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>single</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>responses</span> <span style=''>or</span> <span style=''>a</span> <span style=''>vector</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>responses</span> <span style=''>yet</span> <span style=''>many</span> <span style=''>types</span> <span style=''>of</span> <span style=''>response</span> <span style=''>are</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>organized</span> <span style=''>as</span> <span style=''>matrices</span> <span style=''>or</span> <span style=''>higher</span> <span style=''>order</span> <span style=''>tensor</span> <span style=''>objects</span> <span style=''>where</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characteristics</span> <span style=''>are</span> <span style=''>shared</span> <span style=''>across</span> <span style=''>modes</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>BaTFLED</span> <span style=''>(Bayesian</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <span style=''>Linked</span> <span style=''>to</span> <span style=''>External</span> <span style=''>Data)</span> <span style=''>that</span> <span style=''>predicts</span> <span style=''>values</span> <span style=''>in</span> <span style=''>a</span> <span style=''>three</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>response</span> <span style=''>tensor</span> <span style=''>using</span> <span style=''>input</span> <span style=''>features</span> <span style=''>for</span> <span style=''>each</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>BaTFLED</span> <span style=''>uses</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>learn</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projection</span> <span style=''>matrices</span> <span style=''>mapping</span> <span style=''>input</span> <span style=''>features</span> <span style=''>for</span> <span style=''>each</span> <span style=''>mode</span> <span style=''>into</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>that</span> <span style=''>multiply</span> <span style=''>to</span> <span style=''>form</span> <span style=''>the</span> <span style=''>response</span> <span style=''>tensor</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>utilizing</span> <span style=''>a</span> <span style=''>Tucker</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>the</span> <span style=''>model</span> <span style=''>can</span> <span style=''>capture</span> <spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08247422680412371)
# 	knowledge (0.12228937077852826)
# 	information (0.2552435122644863)
# 	representation (0.135087095627444)
# 	experimental (0.14077497333807323)
# 	segmentation (0.0796302879488091)
# 	different (0.2598649129043726)
# 	detection (0.1226448631354426)
# 	recognition (0.1265552790615002)
# 	convolutional (0.13686455741201564)
#
# Some Statistics words are:
# 	stochastic (0.1404126824358329)
# 	variables (0.13940613990941117)
# 	theoretical (0.1545042778057373)
# 	statistical (0.16255661801711122)
# 	estimation (0.1746351283341721)
# 	algorithm (0.40412682435832914)
# 	distribution (0.1992954202315048)
# 	dimensional (0.19325616507297433)
# 	inference (0.20533467539003522)
# 	regression (0.18369401107196778)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ee4c22ae-f910-4e59-a04c-b269241beaf0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee4c22ae-f910-4e59-a04c-b269241beaf0")) {                    Plotly.newPlot(                        "ee4c22ae-f910-4e59-a04c-b269241beaf0",                        [{"x":["identification","consensus","heterogeneous","applications","motivated","simultaneous","computationally","biomedical","demonstrate","estimation","application","independent","statistical","integrated","clustering","separately","integrative","framework","available","clusterings","individual","assumption","hierarchy","multitask","regression","structure","hierarchical","groupings","approximates","methodologies","variables","varieties","predictive","usefulness","interesting","discovering","automated","simultaneously","phenotypes","discovered","parameters","performance","perspective","information","automatically","inferring","coordinates","cartesian","predicted","naturally","positivity","promising","evaluation","regressor","approaches","generalization","observations","detecting","advantage","consistent","hypothesize","estimates","construction","qualitative","quantitative","architectures","representing","addresses","formulating","alternative","breakthroughs","reconstruction","detection","integrating","discussed","registration","described","strategies","challenges","potential","different","classification","viewpoint","fertilization","complementary","observation","illumination","understanding","impossible","acquisition","geographic","orientation","satellite","challenging","combination","represent","perplexity","baselines","benchmark","evaluated","hungarian","introduced","comparable","documented","processor","collected","automatic","efficiency","artificial","projection","processing","experiment","recognize","characters","character","algorithm","recognition","accurately","population","component","nonlinear","contrastive","selection","discovery","interpretations","desirable","geometrical","dependent","important","homogeneous","denoising","treatment","technique","principal","documentation","experiments","dimensional","standardization","visualizing","identifies","demonstrating","satisfies","guarantees","theoretical","deterministic","incomparable","translation","knowledge","transducer","canonical","existence","transducers","researchers","exploration","reduction","methodology","encodings","empirically","optimization","diversity","improvements","including","contextual","bootstrap","reinforcing","practitioners","remarkably","minimizing","practical","reference","algorithms","introduce","challenge","independently","representation","horizontal","especially","leaderboard","hippocampus","consequences","hippocampal","mechanism","formation","motivation","behaviorally","computation","modulation","complexity","implement","sensitive","convolutional","constrained","cognitive","biological","preserved","respectively","enclosing","unsupervised","extensive","randomized","techniques","supervised","resolving","competitive","approximating","nonparametric","functions","resorting","invariant","expressive","equivalent","competing","forecasting","covariance","demonstrated","arbitrarily","processes","approximations","requirement","inductive","initialization","therefore","components","particularly","uncertainty","resulting","determined","distributions","regularization","algebraic","distribution","properties","modelling","efficient","covariances","extrapolation","stationary","introduces","benchmarks","reasonable","predictions","chervonenkis","generalize","experimental","indicating","conventional","dimension","generally","unbounded","representations","hyperplane","programming","regressors","parameter","performi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	phenotypes
# 	reinforcing
# 	hippocampus
# 	hippocampal
# 	invaluable
# 	textitfixed
# 	therapies
# 	diagnosed
# 	practitioner
# 	marginalized
# 	factorize
# 	bivariate
# 	integrations
# 	corollary
# 	nesterovs
# 	distributedly
# 	bernstein
# 	frequentist
# 	underestimates
# 	bhattacharya
# Some words which never appear in Statistics papers:
# 	cartesian
# 	breakthroughs
# 	fertilization
# 	geographic
# 	hungarian
# 	incomparable
# 	transducer
# 	transducers
# 	unification
# 	connective
# 	decidable
# 	undecidable
# 	termination
# 	continued
# 	unreasonable
# 	purposefully
# 	assertions
# 	underwater
# 	perceives
# 	underperform

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.061286965040103e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7575
